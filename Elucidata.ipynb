# %%
# Converting the gct format into xls format for (PAAD.gct) for loading the data into the notebook
#Using pandas
#Importing some extension libraries
#Reading the whole expression data

# %%
import pandas as pd
paad_datafile=pd.read_table('F:/hb.xlsx')

# %%
paad_datafile
# Out:
#                   #1.3                Unnamed: 1                Unnamed: 2  \
# 0                18465                       183                       NaN
# 1                   id  aab1-Primary solid Tumor  aab4-Primary solid Tumor
# 2       participant_id                      aab1                      aab4
# 3          sample_type       Primary solid Tumor       Primary solid Tumor
# 4      mRNAseq_cluster                         1                         2
# ...                ...                       ...                       ...
# 18586           ZYG11B                       9.2                       9.3
# 18587              ZYX                      12.9                      12.4
# 18588            ZZEF1                      10.1                       9.8
# 18589             ZZZ3                       9.3                       8.9
# 18590        psiTPTE22                       5.5                       4.5
#
#                      Unnamed: 3                Unnamed: 4  \
# ...

# %%
paad_datafile.shape
# Out:
# (18591, 184)

# %%
paad_datafile.isna()
# Out:
#         #1.3  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      False       False        True        True        True        True
# 1      False       False       False       False       False       False
# 2      False       False       False       False       False       False
# 3      False       False       False       False       False       False
# 4      False       False       False       False       False       False
# ...      ...         ...         ...         ...         ...         ...
# 18586  False       False       False       False       False       False
# 18587  False       False       False       False       False       False
# 18588  False       False       False       False       False       False
# 18589  False       False       False       False       False       False
# 18590  False       False       False       False       False       False
#
#        Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 174  \
# ...

# %%
paad_datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18591 entries, 0 to 18590
# Columns: 184 entries, #1.3 to Unnamed: 183
# dtypes: object(184)
# memory usage: 26.1+ MB

# %%
#Replacing the NaN value using using fill na

# %%
paad_datafile=paad_datafile.fillna(0)

# %%
paad_datafile
# Out:
#                   #1.3                Unnamed: 1                Unnamed: 2  \
# 0                18465                       183                         0
# 1                   id  aab1-Primary solid Tumor  aab4-Primary solid Tumor
# 2       participant_id                      aab1                      aab4
# 3          sample_type       Primary solid Tumor       Primary solid Tumor
# 4      mRNAseq_cluster                         1                         2
# ...                ...                       ...                       ...
# 18586           ZYG11B                       9.2                       9.3
# 18587              ZYX                      12.9                      12.4
# 18588            ZZEF1                      10.1                       9.8
# 18589             ZZZ3                       9.3                       8.9
# 18590        psiTPTE22                       5.5                       4.5
#
#                      Unnamed: 3                Unnamed: 4  \
# ...

# %%
#Nan can be removed by grouping the NaN column by the median value

# %%
paad_datafile.isnull().sum()
# Out:
# #1.3            0
# Unnamed: 1      0
# Unnamed: 2      0
# Unnamed: 3      0
# Unnamed: 4      0
#                ..
# Unnamed: 179    0
# Unnamed: 180    0
# Unnamed: 181    0
# Unnamed: 182    0
# Unnamed: 183    0
# Length: 184, dtype: int64

# %%
paad_datafile.notnull
# Out:
# <bound method DataFrame.notnull of                   #1.3                Unnamed: 1                Unnamed: 2  \
# 0                18465                       183                         0
# 1                   id  aab1-Primary solid Tumor  aab4-Primary solid Tumor
# 2       participant_id                      aab1                      aab4
# 3          sample_type       Primary solid Tumor       Primary solid Tumor
# 4      mRNAseq_cluster                         1                         2
# ...                ...                       ...                       ...
# 18586           ZYG11B                       9.2                       9.3
# 18587              ZYX                      12.9                      12.4
# 18588            ZZEF1                      10.1                       9.8
# 18589             ZZZ3                       9.3                       8.9
# 18590        psiTPTE22                       5.5                       4.5
#
# ...

# %%
pd.Series([True,False,True])
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
pd.Series([True,False,True]).sum()
# Out:
# 2

# %%
paad_datafile.dropna(subset=['#1.3'],how='all').shape
# Out:
# (18591, 184)

# %%
paad_datafile.dropna(how='all').shape
# Out:
# (18591, 184)

# %% [markdown]
# paad_datafile['Unnamed: 1'].value_counts()

# %% [markdown]
# #Using ![title]('F:/newplot.png') to add the PCA image

# %% [markdown]
# ![title]('F:/newplot.png')
